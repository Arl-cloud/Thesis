# %% [markdown]
# ## Scrape non-retracted pdfs to text

# %% [markdown]
# Connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
files = os.listdir('.')

# %% [markdown]
# Set directory of the folder where the downloads are placed in

# %%
cd '/content/drive/MyDrive/Thesis_UU/push/3group/Downloads (paper pdfs)/Downloads_non_retracted'
# Out:
# /content/drive/MyDrive/Thesis_UU/Common_20_05_2022/Code/Downloads (paper pdfs)/Downloads_non_retracted

# %% [markdown]
# Scrape text of pdfs, insert into dataframe

# %%
# !pip install pymupdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymupdf
#   Downloading PyMuPDF-1.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 5.1 MB/s
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.19.6

# %%
import pandas as pd
import fitz  # this is pymupdf
df_non_retracted = pd.DataFrame(columns=['DOI', 'Content', 'Retracted']) #make empty dataframe
for study in files: #iterate through the files
  try:
    with fitz.open(study) as doc: #open the document
        text = "" #start with empty string
        for page in doc: #iterate through the pages of the file
            text += page.get_text() #add the found text to the empty string
        df_non_retracted = df_non_retracted.append({'DOI': study, 'Content': text, 'Retracted': 0}, ignore_index=True) #add DOI, text and 0 for non-retracted paper to the dataframe
  except: #if anything above fails, pass this file
    pass

# %%
df_non_retracted.head(2)
# Out:
#           DOI                                            Content Retracted
# 0  nr4461.pdf  CORRECTION\nCorrection: Spinal Cord Transectio...         0
# 1  nr4462.pdf  Correction\nCorrection: Genome-Wide Comparativ...         0

# %%
len(df_non_retracted)
# Out:
# 3009

# %% [markdown]
# Save dataframe to a csv file

# %%
df_non_retracted.to_csv('/content/drive/MyDrive/Thesis_UU/push/3group/Data (CSV)/non_retracted_papers.csv', index=False, encoding = 'utf-8-sig')

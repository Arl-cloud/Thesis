# %% [markdown]
# ## Merge meta non-retracted

# %% [markdown]
# Connect to drive, set directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Thesis_UU/push/3group/'
# Out:
# /content/drive/MyDrive/Thesis_UU/Common_20_05_2022/Code

# %% [markdown]
# Non-retracted

# %%
import pandas as pd

# %%
df_non_retracted = pd.read_csv('Data (CSV)/non_retracted_papers.csv') 
df_meta_non_retracted = pd.read_csv('Data (CSV)/meta_non_retracted.csv')

# %%
df_non_retracted['ID'] = df_non_retracted.DOI.str.replace('.pdf', '', regex = True) #remove ".pdf" from ID

# %%
nr_result = pd.merge(df_non_retracted, df_meta_non_retracted, on="ID") #merge meta and content data

# %%
len(nr_result)
# Out:
# 3009

# %%
nr_result.head(2)
# Out:
#         DOI_x                                            Content  Retracted  \
# 0  nr4461.pdf  CORRECTION\nCorrection: Spinal Cord Transectio...          0
# 1  nr4462.pdf  Correction\nCorrection: Genome-Wide Comparativ...          0
#
#        ID  Unnamed: 0 Publication Type Authors  Book Authors  Book Editors  \
# 0  nr4461        4461                J     NaN           NaN           NaN
# 1  nr4462        4462                J     NaN           NaN           NaN
#
#    Book Group Authors  ... IDS Number  Pubmed Id  \
# 0                 NaN  ...      CD7QC        NaN
# 1                 NaN  ...      AM0QO        NaN
#
#                  Open Access Designations Highly Cited Status  \
# 0  Green Submitted, Green Published, gold                 NaN
# 1  Green Submitted, Green Published, gold                 NaN
#
#   Hot Paper Status  Date of Export   UT (Unique WOS ID) index class    year
# 0              NaN      2022-06-03  WOS:000351284600016  4461    nr  1970.0
# 1              NaN      2022-06-03  WOS:000339551100106  4462    nr  1970.0
#
# [2 rows x 78 columns]

# %%
nr_result.tail(2)
# Out:
#           DOI_x                                            Content  Retracted  \
# 3007  nr514.pdf  Ž\n.\nBrain Research 858 2000 237–251\nwww.els...          0
# 3008  nr515.pdf  Ž\n.\nBrain Research 803 1998 218–230\nInterac...          0
#
#          ID  Unnamed: 0 Publication Type  \
# 3007  nr514         514                J
# 3008  nr515         515                J
#
#                                                 Authors  Book Authors  \
# 3007               Maldonado, TA; Jones, RE; Norris, DO           NaN
# 3008  Groothuis, DR; Ward, S; Schlageter, KE; Itskov...           NaN
#
#       Book Editors  Book Group Authors  ... IDS Number   Pubmed Id  \
# 3007           NaN                 NaN  ...      292VB  10708675.0
# 3008           NaN                 NaN  ...      115MB   9729397.0
#
#      Open Access Designations Highly Cited Status Hot Paper Status  \
# 3007                      NaN                 NaN              NaN
# 3008                      NaN                 NaN              NaN
#
#       Date of Export   UT (Unique WOS ID) index class    year
# 3007      2022-06-03  WOS:000085814800002   514    nr  1970.0
# 3008      2022-06-03  WOS:000075667900030   515    nr  1970.0
#
# [2 rows x 78 columns]

# %%
nr_result.columns
# Out:
# Index(['DOI_x', 'Content', 'Retracted', 'ID', 'Unnamed: 0', 'Publication Type',
#        'Authors', 'Book Authors', 'Book Editors', 'Book Group Authors',
#        'Author Full Names', 'Book Author Full Names', 'Group Authors',
#        'Article Title', 'Source Title', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Author Keywords', 'Keywords Plus', 'Abstract',
#        'Addresses', 'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Publication Year', 'Volume', 'Issue', 'Part Number', 'Supplement',
#        'Special Issue', 'Meeting Abstract', 'Start Page', 'End Page',
#        'Article Number', 'DOI_y', 'Book DOI', 'Early Access Date',
#        'Number of Pages', 'WoS Categories', 'Web of Science Index',
#        'Research Areas', 'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'index', 'class', 'year'],
#       dtype='object')

# %%
nr_result.rename(columns={"Source Title": "Source_Title"}, inplace = True)

# %%
len(set(nr_result['Source_Title'])) #amount of journals
# Out:
# 73

# %%
non_retracted_journals = nr_result.groupby(['Source_Title']).size().reset_index(name='Amount').sort_values(by = 'Amount', ascending = False)
non_retracted_journals #check which journals contain how many papers
# Out:
#                                          Source_Title  Amount
# 63                                           PLOS ONE     351
# 40                   JOURNAL OF CELLULAR BIOCHEMISTRY     239
# 65  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCE...     144
# 57                         MOLECULAR MEDICINE REPORTS      98
# 72                                      TUMOR BIOLOGY      95
# ..                                                ...     ...
# 43                              JOURNAL OF IMMUNOLOGY       6
# 62                               NEUROSCIENCE LETTERS       5
# 70                           SCIENTIFIC WORLD JOURNAL       4
# 64                                           PLoS One       1
# 35         INTERNATIONAL JOURNAL OF CLINICAL PRACTICE       1
#
# [73 rows x 2 columns]

# %%
non_retracted_journals.to_csv('Data (CSV)/non_retracted_journals.csv') #save journal df to csv

# %%
nr_result.to_csv('Data (CSV)/non_retracted.csv') #save merged data to csv

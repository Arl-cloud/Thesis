# %% [markdown]
# ## Scrape retracted (due to error) pdfs to text

# %% [markdown]
# Connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
files = os.listdir('.')

# %% [markdown]
# Set directory of the folder where the downloads are placed in

# %%
cd '/content/drive/MyDrive/Thesis_UU/push/3group/Downloads (paper pdfs)/Downloads_retracted_error'

# %% [markdown]
# Scrape text of pdfs, insert into dataframe

# %%
# !pip install pymupdf

# %%
import pandas as pd
import fitz  # this is pymupdf
df_error = pd.DataFrame(columns=['DOI', 'Content', 'Retracted'])
for study in files:
  try:
    with fitz.open(study) as doc:
        text = ""
        for page in doc:
            text += page.get_text()
        df_error = df_error.append({'DOI': study, 'Content': text, 'Retracted': 1}, ignore_index=True)
  except:
    pass

df_error

# %%
df_error.to_csv('/content/drive/MyDrive/Thesis_UU/push/3group/Data (CSV)/retracted_error_papers.csv', index=False, encoding = 'utf-8-sig')

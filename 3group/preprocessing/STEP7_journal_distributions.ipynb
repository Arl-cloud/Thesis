# %% [markdown]
# Connect to drive, set directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Thesis_UU/push/3group'
# Out:
# /content/drive/MyDrive/Thesis_UU/Common_20_05_2022/Code

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import re

# %% [markdown]
# ## External validation dataset

# %%
journal_test_data_set = pd.read_csv('Data (CSV)/journal_test_data_set.csv')

# %%
len(journal_test_data_set)
# Out:
# 367

# %% [markdown]
# Investigate group sizes

# %%
classes = journal_test_data_set.groupby(['class']).count().reset_index()
classes
# Out:
#   class  Unnamed: 0  Unnamed: 0.1   ID  All content  Text  Journal_Name  \
# 0     e          39            39   39           39    39            39
# 1     m          79            79   79           79    79            79
# 2    nr         249           249  249          249   249           249
#
#    Retracted  preprocessed
# 0         39            39
# 1         79            79
# 2        249           249

# %%
len(set(journal_test_data_set.Journal_Name)) #amount of journals
# Out:
# 2

# %% [markdown]
# Create df of journals with group size per journals

# %%
journals_test = journals_test.unstack('class').reset_index()

# %%
journals_test.rename(columns={"Journal_Name": "journal", "e": "error", "m": "misconduct", "nr": "non-retracted"}, inplace = True)

# %%
journals_test['total']= journals_test.sum(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
journals_test
# Out:
# class                     journal  error  misconduct  non-retracted  total
# 0      molecular medicine reports      5          18             92    115
# 1                        plos one     34          61            157    252

# %% [markdown]
# Save df

# %%
journals_test.to_csv('Data (CSV)/journals_test.csv')

# %% [markdown]
# ## Train/test dataset

# %%
journal_train_data_set = pd.read_csv('Data (CSV)/journal_train_data_set.csv')

# %%
len(journal_train_data_set)
# Out:
# 1117

# %% [markdown]
# Investigate group sizes

# %%
classes = journal_train_data_set.groupby(['class']).count().reset_index()
classes
# Out:
#   class  Unnamed: 0  Unnamed: 0.1   ID  All content  Text  Journal_Name  \
# 0     e         119           119  119          119   119           119
# 1     m         306           306  306          306   306           306
# 2    nr         692           692  692          692   692           692
#
#    Retracted  preprocessed
# 0        119           119
# 1        306           306
# 2        692           692

# %%
len(set(journal_train_data_set.Journal_Name)) #amount of journals
# Out:
# 40

# %% [markdown]
# Create df of journals with group size per journals

# %%
journals_train = journals_train.unstack('class').reset_index()

# %%
journals_train.rename(columns={"Journal_Name": "journal", "e": "error", "m": "misconduct", "nr": "non-retracted"}, inplace = True)

# %%
journals_train['total']= journals_train.sum(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
journals_train
# Out:
# class                                            journal  error  misconduct  \
# 0                     acs applied materials & interfaces      2           7
# 1        artificial cells nanomedicine and biotechnology      2          12
# 2                               biochemical pharmacology      2           2
# 3                          biomed research international      5           5
# 4                                                  blood      3           2
# 5                                         brain research      3           2
# 6                            canadian journal of physics      3           3
# 7                                    cancer gene therapy      2           6
# 8                                         cancer letters      7           8
# 9                                        cancer research      6          26
# 10                                                  cell      5           6
# 11                                            cell cycle      2           5
# 12                                       cell metabolism      3           4
# 13                   construction and building materials      2           6
# 14                                          embo journal      5           2
# 15     evidence-based complementary and alternative m...      1           2
# 16                 experimental and therapeutic medicine      1          17
# 17                            experimental cell research      3           2
# 18           industrial & engineering chemistry research      1           5
# 19                      international immunopharmacology      2           2
# 20                       journal of biological chemistry      1           8
# 21                  journal of bone and mineral research      2           1
# 22                               journal of cell science      2           5
# 23                      journal of cellular biochemistry      7          70
# 24                        journal of cellular physiology      8          18
# 25                         journal of controlled release      1           3
# 26                               journal of neuroscience      8           4
# 27              journal of the american chemical society      1           2
# 28                                                lancet      3           2
# 29                                         life sciences      2           8
# 30                     materials science and engineering      2           3
# 31                  mathematical problems in engineering      2           3
# 32                                              medicine      5           2
# 33         naunyn-schmiedebergs archives of pharmacology      2           6
# 34                                        neurocomputing      2           1
# 35                                      renewable energy      1           2
# 36                                          rsc advances      5          20
# 37                              scientific world journal      1           3
# 38                                      thin solid films      2           2
# 39                                         tumor biology      2          19
#
# class  non-retracted  total
# 0                 31     40
# 1                 42     56
# 2                  1      5
# 3                  9     19
# 4                 14     19
# 5                 15     20
# 6                 20     26
# 7                 12     20
# 8                 13     28
# 9                 42     74
# 10                40     51
# 11                18     25
# 12                25     32
# 13                33     41
# 14                 2      9
# 15                 4      7
# 16                56     74
# 17                20     25
# 18                 9     15
# 19                 7     11
# 20                 4     13
# 21                15     18
# 22                16     23
# 23                33    110
# 24                14     40
# 25                 7     11
# 26                 5     17
# 27                 3      6
# 28                 2      7
# 29                22     32
# 30                11     16
# 31                23     28
# 32                15     22
# 33                 2     10
# 34                 9     12
# 35                11     14
# 36                 1     26
# 37                 3      7
# 38                 9     13
# 39                74     95

# %% [markdown]
# Save df

# %%
journals_train.to_csv('Data (CSV)/journals_train.csv')
